# %% [markdown]
# # Livrable 2 :

# %%
import tensorflow as tf
import numpy as np
import os
import sys
from tensorflow import keras

project_root = os.path.abspath(os.path.join(".."))  # One level up from current script
if project_root not in sys.path:
    sys.path.append(project_root)

from src.model_loader import ModelLoader
from src.data_loader import DataLoader
from src.utils import get_confusion_matrix, get_classification_report

print(tf.__version__)
# Out:
# 2.19.0

# %% [markdown]
# ## Généation du dataset de photos

# %%
data_loader = DataLoader()
train_ds, test_ds, val_ds = data_loader.load_unique_dataset(folder_name="/mnt/c/Users/louag/Documents/CESI/Data_science/datasets/Photo")
# Out:
# Photo Dataset size: 9993

# %% [markdown]
# ## Bruitage du dataset

# %%
noisy_train_ds = data_loader.add_noise_to_dataset(train_ds)
noisy_val_ds = data_loader.add_noise_to_dataset(val_ds)
noisy_test_ds = data_loader.add_noise_to_dataset(test_ds)

# %%
from keras.layers import Input, Conv2D, BatchNormalization, LeakyReLU
from keras.models import Model

encoder_inputs = Input(shape=(256, 256, 3))  # Image RGB 256x256

# Conv Block 1
x = Conv2D(32, (3, 3), strides=2, padding='same')(encoder_inputs)  # (128, 128, 32)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

# Conv Block 2
x = Conv2D(64, (3, 3), strides=2, padding='same')(x)  # (64, 64, 64)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

# Conv Block 3
x = Conv2D(128, (3, 3), strides=2, padding='same')(x)  # (32, 32, 128)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

# Conv Block 4
x = Conv2D(256, (3, 3), strides=2, padding='same')(x)  # (16, 16, 256)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

# Conv Block 5
x = Conv2D(256, (3, 3), strides=2, padding='same')(x)  # (8, 8, 256)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

encoder_output = x  # Pas de flatten, on garde (8, 8, 256)

encoder = Model(encoder_inputs, encoder_output, name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 8, 8, 256)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 981,440 (3.74 MB)
#  Trainable params: 979,968 (3.74 MB)
#  Non-trainable params: 1,472 (5.75 KB)

# %%
from keras.layers import Input, Conv2DTranspose, BatchNormalization, LeakyReLU, Conv2D
from keras.models import Model

# --- Decoder simplifié ---
decoder_inputs = Input(shape=(8, 8, 256))  # Sortie directe de l'encodeur

# DeConv1
x = Conv2DTranspose(128, (3, 3), strides=(2, 2), padding='same')(decoder_inputs)  # (16, 16, 128)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

# DeConv2
x = Conv2DTranspose(128, (3, 3), strides=(2, 2), padding='same')(x)  # (32, 32, 128)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

# DeConv3
x = Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same')(x)  # (64, 64, 64)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

# DeConv4
x = Conv2DTranspose(32, (3, 3), strides=(2, 2), padding='same')(x)  # (128, 128, 32)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

# DeConv5 - reconstruction finale
x = Conv2DTranspose(32, (3, 3), strides=(2, 2), padding='same')(x)  # (256, 256, 32)
decoder_output = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)  # Sortie finale RGB

# Modèle decoder
decoder = Model(decoder_inputs, decoder_output, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 16, 16, 128)    │       295,040 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_5 (LeakyReLU)       │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 32, 32, 128)    │       147,584 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_6 (LeakyReLU)       │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 64, 64, 64)     │        73,792 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_7 (LeakyReLU)       │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 128, 128, 32)   │        18,464 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_8 (LeakyReLU)       │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 256, 256, 32)   │         9,248 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 256, 256, 3)    │           867 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 546,403 (2.08 MB)
#  Trainable params: 545,699 (2.08 MB)
#  Non-trainable params: 704 (2.75 KB)

# %%
decoder.summary()
# Out:
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 16, 16, 128)    │       295,040 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_5 (LeakyReLU)       │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 32, 32, 128)    │       147,584 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_6 (LeakyReLU)       │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 64, 64, 64)     │        73,792 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_7 (LeakyReLU)       │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 128, 128, 32)   │        18,464 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_8 (LeakyReLU)       │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 256, 256, 32)   │         9,248 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 256, 256, 3)    │           867 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 546,403 (2.08 MB)
#  Trainable params: 545,699 (2.08 MB)
#  Non-trainable params: 704 (2.75 KB)

# %%
def ssim_loss(y_true, y_pred):
    return 1 - tf.reduce_mean(tf.image.ssim(y_true, y_pred, max_val=1.0))

# %%
# -- Metrics Custom --
def ssim_metric(y_true, y_pred):
    # SSIM attend des valeurs entre [0, 1], donc il est important de s'assurer que les images sont dans cette plage.
    y_true = tf.clip_by_value(y_true, 0.0, 1.0)  # Pour être sûr que les valeurs sont entre [0, 1]
    y_pred = tf.clip_by_value(y_pred, 0.0, 1.0)  # Pour être sûr que les valeurs sont entre [0, 1]
    
    # Calcul du SSIM sur les images RGB
    return tf.reduce_mean(tf.image.ssim(y_true, y_pred, max_val=1.0))  # max_val=1.0 pour les images normalisées

def psnr_metric(y_true, y_pred):
    # PSNR attend des valeurs entre [0, 1], donc on s'assure que les images sont dans cette plage.
    y_true = tf.clip_by_value(y_true, 0.0, 1.0)  # Normalisation entre [0, 1]
    y_pred = tf.clip_by_value(y_pred, 0.0, 1.0)  # Normalisation entre [0, 1]
    
    # Calcul du PSNR sur les images RGB
    return tf.reduce_mean(tf.image.psnr(y_true, y_pred, max_val=1.0))  # max_val=1.0 pour les images normalisées

# %%
from tensorflow.keras.models import Model

# On récupère la sortie de l'encodeur (le "latent space")
latent_space = encoder(encoder_inputs)

# On passe cette sortie directement dans le décodeur
outputs = decoder(latent_space)

# Maintenant, on crée l'autoencodeur avec l'encodeur et le décodeur
autoencoder = Model(encoder_inputs, outputs, name="autoencoder")

# Compilation de l'autoencodeur
autoencoder.compile(optimizer="adam", loss=ssim_loss, metrics=["mae", ssim_metric, psnr_metric])

# Résumé du modèle
autoencoder.summary()
# Out:
# Model: "autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder (Functional)            │ (None, 8, 8, 256)      │       981,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder (Functional)            │ (None, 256, 256, 3)    │       546,403 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,527,843 (5.83 MB)
#  Trainable params: 1,525,667 (5.82 MB)
#  Non-trainable params: 2,176 (8.50 KB)

# %%
@tf.autograph.experimental.do_not_convert
def make_autoencoder_dataset(input_ds, target_ds):
    return tf.data.Dataset.zip((input_ds.map(lambda x, y: x), target_ds.map(lambda x, y: x)))

# %%
train_autoenc_ds = make_autoencoder_dataset(noisy_train_ds, train_ds)
val_autoenc_ds = make_autoencoder_dataset(noisy_val_ds, val_ds)

# %%
# Train the model
with tf.device("/gpu:0"):
    history = autoencoder.fit(train_autoenc_ds,
                    epochs=100,
                    batch_size= 64,
                    shuffle= True,
                    validation_data=val_autoenc_ds,
                    verbose=1
                   )
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1744916627.589637   43747 service.cc:152] XLA service 0x7f3cb4124b50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1744916627.589690   43747 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3070 Laptop GPU, Compute Capability 8.6
# 2025-04-17 21:03:48.141325: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-04-17 21:03:49.308093: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/ssim_loss/SSIM/Assert/Assert
# 2025-04-17 21:03:49.309844: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/ssim_loss/SSIM/Assert_1/Assert
# 2025-04-17 21:03:49.310975: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/ssim_loss/SSIM/Assert_2/Assert
# 2025-04-17 21:03:49.311892: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/ssim_loss/SSIM/Assert_3/Assert
# 2025-04-17 21:03:49.312161: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator SSIM/Assert/Assert
# 2025-04-17 21:03:49.312352: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator SSIM/Assert_1/Assert
# 2025-04-17 21:03:49.313401: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator SSIM/Assert_2/Assert
# 2025-04-17 21:03:49.314024: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator SSIM/Assert_3/Assert
# 2025-04-17 21:03:49.314239: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator PSNR/Assert/Assert
# 2025-04-17 21:03:49.314414: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator PSNR/Assert_1/Assert
# I0000 00:00:1744916629.818752   43747 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1744916645.191342   43747 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.6716 - mae: 0.1896 - psnr_metric: 13.1276 - ssim_metric: 0.3284
# 2025-04-17 21:04:31.993832: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/ssim_loss/SSIM/Assert/Assert
# 2025-04-17 21:04:31.994114: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/ssim_loss/SSIM/Assert_1/Assert
# 2025-04-17 21:04:31.994371: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/ssim_loss/SSIM/Assert_2/Assert
# 2025-04-17 21:04:31.994517: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/ssim_loss/SSIM/Assert_3/Assert
# 2025-04-17 21:04:31.994553: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator SSIM/Assert/Assert
# 2025-04-17 21:04:31.994564: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator SSIM/Assert_1/Assert
# 2025-04-17 21:04:31.994853: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator SSIM/Assert_2/Assert
# 2025-04-17 21:04:31.994997: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator SSIM/Assert_3/Assert
# 2025-04-17 21:04:31.995030: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator PSNR/Assert/Assert
# 2025-04-17 21:04:31.995040: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator PSNR/Assert_1/Assert
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 73s 253ms/step - loss: 0.6711 - mae: 0.1892 - psnr_metric: 13.1454 - ssim_metric: 0.3289 - val_loss: 0.6651 - val_mae: 0.2753 - val_psnr_metric: 10.1591 - val_ssim_metric: 0.3352
# Epoch 2/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 164ms/step - loss: 0.5348 - mae: 0.1010 - psnr_metric: 17.5602 - ssim_metric: 0.4652 - val_loss: 0.5468 - val_mae: 0.1366 - val_psnr_metric: 15.7223 - val_ssim_metric: 0.4535
# Epoch 3/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 165ms/step - loss: 0.4937 - mae: 0.0964 - psnr_metric: 17.9283 - ssim_metric: 0.5063 - val_loss: 0.4842 - val_mae: 0.1007 - val_psnr_metric: 17.6045 - val_ssim_metric: 0.5161
# Epoch 4/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 165ms/step - loss: 0.4767 - mae: 0.0942 - psnr_metric: 18.1221 - ssim_metric: 0.5233 - val_loss: 0.4824 - val_mae: 0.0941 - val_psnr_metric: 18.1410 - val_ssim_metric: 0.5180
# Epoch 5/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 165ms/step - loss: 0.4665 - mae: 0.0931 - psnr_metric: 18.2325 - ssim_metric: 0.5335 - val_loss: 0.4724 - val_mae: 0.0925 - val_psnr_metric: 18.2726 - val_ssim_metric: 0.5280
# Epoch 6/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 165ms/step - loss: 0.4595 - mae: 0.0921 - psnr_metric: 18.3203 - ssim_metric: 0.5405 - val_loss: 0.4715 - val_mae: 0.0916 - val_psnr_metric: 18.3572 - val_ssim_metric: 0.5289
# Epoch 7/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 165ms/step - loss: 0.4544 - mae: 0.0915 - psnr_metric: 18.3741 - ssim_metric: 0.5456 - val_loss: 0.4647 - val_mae: 0.0908 - val_psnr_metric: 18.4241 - val_ssim_metric: 0.5357
# Epoch 8/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 165ms/step - loss: 0.4504 - mae: 0.0910 - psnr_metric: 18.4223 - ssim_metric: 0.5496 - val_loss: 0.4651 - val_mae: 0.0900 - val_psnr_metric: 18.5045 - val_ssim_metric: 0.5353
# Epoch 9/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 166ms/step - loss: 0.4471 - mae: 0.0905 - psnr_metric: 18.4745 - ssim_metric: 0.5529 - val_loss: 0.4618 - val_mae: 0.0911 - val_psnr_metric: 18.3926 - val_ssim_metric: 0.5386
# Epoch 10/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 165ms/step - loss: 0.4442 - mae: 0.0901 - psnr_metric: 18.5136 - ssim_metric: 0.5558 - val_loss: 0.4613 - val_mae: 0.0902 - val_psnr_metric: 18.4812 - val_ssim_metric: 0.5391
# Epoch 11/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 165ms/step - loss: 0.4416 - mae: 0.0888 - psnr_metric: 18.6189 - ssim_metric: 0.5584 - val_loss: 0.4507 - val_mae: 0.0819 - val_psnr_metric: 19.2074 - val_ssim_metric: 0.5497
# Epoch 12/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 166ms/step - loss: 0.4344 - mae: 0.0803 - psnr_metric: 19.3694 - ssim_metric: 0.5656 - val_loss: 0.4443 - val_mae: 0.0745 - val_psnr_metric: 19.9023 - val_ssim_metric: 0.5560
# Epoch 13/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 165ms/step - loss: 0.4309 - mae: 0.0775 - psnr_metric: 19.6418 - ssim_metric: 0.5691 - val_loss: 0.4439 - val_mae: 0.0726 - val_psnr_metric: 20.0639 - val_ssim_metric: 0.5565
# Epoch 14/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 166ms/step - loss: 0.4286 - mae: 0.0762 - psnr_metric: 19.7650 - ssim_metric: 0.5714 - val_loss: 0.4346 - val_mae: 0.0700 - val_psnr_metric: 20.3204 - val_ssim_metric: 0.5658
# Epoch 15/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.4262 - mae: 0.0752 - psnr_metric: 19.8677 - ssim_metric: 0.5738 - val_loss: 0.4332 - val_mae: 0.0729 - val_psnr_metric: 20.0441 - val_ssim_metric: 0.5672
# Epoch 16/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 166ms/step - loss: 0.4246 - mae: 0.0747 - psnr_metric: 19.9182 - ssim_metric: 0.5754 - val_loss: 0.4266 - val_mae: 0.0699 - val_psnr_metric: 20.3458 - val_ssim_metric: 0.5737
# Epoch 17/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 166ms/step - loss: 0.4229 - mae: 0.0742 - psnr_metric: 19.9728 - ssim_metric: 0.5771 - val_loss: 0.4307 - val_mae: 0.0704 - val_psnr_metric: 20.2902 - val_ssim_metric: 0.5696
# Epoch 18/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 166ms/step - loss: 0.4216 - mae: 0.0739 - psnr_metric: 20.0049 - ssim_metric: 0.5784 - val_loss: 0.4268 - val_mae: 0.0709 - val_psnr_metric: 20.2471 - val_ssim_metric: 0.5735
# Epoch 19/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 166ms/step - loss: 0.4203 - mae: 0.0734 - psnr_metric: 20.0495 - ssim_metric: 0.5797 - val_loss: 0.4260 - val_mae: 0.0708 - val_psnr_metric: 20.2647 - val_ssim_metric: 0.5743
# Epoch 20/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 166ms/step - loss: 0.4194 - mae: 0.0732 - psnr_metric: 20.0733 - ssim_metric: 0.5806 - val_loss: 0.4246 - val_mae: 0.0701 - val_psnr_metric: 20.3346 - val_ssim_metric: 0.5757
# Epoch 21/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 165ms/step - loss: 0.4183 - mae: 0.0730 - psnr_metric: 20.0986 - ssim_metric: 0.5817 - val_loss: 0.4201 - val_mae: 0.0708 - val_psnr_metric: 20.2630 - val_ssim_metric: 0.5803
# Epoch 22/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 166ms/step - loss: 0.4169 - mae: 0.0726 - psnr_metric: 20.1417 - ssim_metric: 0.5831 - val_loss: 0.4213 - val_mae: 0.0696 - val_psnr_metric: 20.3652 - val_ssim_metric: 0.5791
# Epoch 23/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 166ms/step - loss: 0.4166 - mae: 0.0725 - psnr_metric: 20.1502 - ssim_metric: 0.5834 - val_loss: 0.4210 - val_mae: 0.0689 - val_psnr_metric: 20.4470 - val_ssim_metric: 0.5793
# Epoch 24/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 171ms/step - loss: 0.4154 - mae: 0.0723 - psnr_metric: 20.1733 - ssim_metric: 0.5846 - val_loss: 0.4150 - val_mae: 0.0698 - val_psnr_metric: 20.3860 - val_ssim_metric: 0.5854
# Epoch 25/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 35s 172ms/step - loss: 0.4144 - mae: 0.0721 - psnr_metric: 20.1980 - ssim_metric: 0.5856 - val_loss: 0.4136 - val_mae: 0.0693 - val_psnr_metric: 20.4177 - val_ssim_metric: 0.5868
# Epoch 26/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 35s 172ms/step - loss: 0.4138 - mae: 0.0719 - psnr_metric: 20.2200 - ssim_metric: 0.5862 - val_loss: 0.4174 - val_mae: 0.0673 - val_psnr_metric: 20.6204 - val_ssim_metric: 0.5830
# Epoch 27/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 170ms/step - loss: 0.4129 - mae: 0.0717 - psnr_metric: 20.2452 - ssim_metric: 0.5871 - val_loss: 0.4142 - val_mae: 0.0684 - val_psnr_metric: 20.5197 - val_ssim_metric: 0.5861
# Epoch 28/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.4122 - mae: 0.0715 - psnr_metric: 20.2602 - ssim_metric: 0.5878 - val_loss: 0.4121 - val_mae: 0.0670 - val_psnr_metric: 20.6777 - val_ssim_metric: 0.5882
# Epoch 29/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 35s 172ms/step - loss: 0.4118 - mae: 0.0714 - psnr_metric: 20.2714 - ssim_metric: 0.5882 - val_loss: 0.4136 - val_mae: 0.0681 - val_psnr_metric: 20.5555 - val_ssim_metric: 0.5868
# Epoch 30/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.4108 - mae: 0.0711 - psnr_metric: 20.3005 - ssim_metric: 0.5892 - val_loss: 0.4100 - val_mae: 0.0668 - val_psnr_metric: 20.6755 - val_ssim_metric: 0.5903
# Epoch 31/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.4105 - mae: 0.0709 - psnr_metric: 20.3197 - ssim_metric: 0.5895 - val_loss: 0.4103 - val_mae: 0.0684 - val_psnr_metric: 20.5095 - val_ssim_metric: 0.5900
# Epoch 32/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 35s 174ms/step - loss: 0.4097 - mae: 0.0708 - psnr_metric: 20.3397 - ssim_metric: 0.5903 - val_loss: 0.4108 - val_mae: 0.0679 - val_psnr_metric: 20.5721 - val_ssim_metric: 0.5895
# Epoch 33/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 35s 175ms/step - loss: 0.4091 - mae: 0.0707 - psnr_metric: 20.3516 - ssim_metric: 0.5909 - val_loss: 0.4093 - val_mae: 0.0684 - val_psnr_metric: 20.5235 - val_ssim_metric: 0.5911
# Epoch 34/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 168ms/step - loss: 0.4084 - mae: 0.0703 - psnr_metric: 20.3823 - ssim_metric: 0.5916 - val_loss: 0.4108 - val_mae: 0.0659 - val_psnr_metric: 20.7769 - val_ssim_metric: 0.5896
# Epoch 35/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.4081 - mae: 0.0703 - psnr_metric: 20.3974 - ssim_metric: 0.5919 - val_loss: 0.4134 - val_mae: 0.0656 - val_psnr_metric: 20.8024 - val_ssim_metric: 0.5869
# Epoch 36/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 168ms/step - loss: 0.4078 - mae: 0.0700 - psnr_metric: 20.4172 - ssim_metric: 0.5922 - val_loss: 0.4122 - val_mae: 0.0661 - val_psnr_metric: 20.7467 - val_ssim_metric: 0.5881
# Epoch 37/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 169ms/step - loss: 0.4072 - mae: 0.0699 - psnr_metric: 20.4302 - ssim_metric: 0.5928 - val_loss: 0.4106 - val_mae: 0.0664 - val_psnr_metric: 20.7358 - val_ssim_metric: 0.5897
# Epoch 38/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 36s 177ms/step - loss: 0.4069 - mae: 0.0700 - psnr_metric: 20.4273 - ssim_metric: 0.5931 - val_loss: 0.4099 - val_mae: 0.0662 - val_psnr_metric: 20.7468 - val_ssim_metric: 0.5904
# Epoch 39/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 169ms/step - loss: 0.4060 - mae: 0.0697 - psnr_metric: 20.4547 - ssim_metric: 0.5940 - val_loss: 0.4099 - val_mae: 0.0655 - val_psnr_metric: 20.8111 - val_ssim_metric: 0.5904
# Epoch 40/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 169ms/step - loss: 0.4057 - mae: 0.0695 - psnr_metric: 20.4732 - ssim_metric: 0.5943 - val_loss: 0.4168 - val_mae: 0.0660 - val_psnr_metric: 20.7566 - val_ssim_metric: 0.5835
# Epoch 41/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 168ms/step - loss: 0.4057 - mae: 0.0693 - psnr_metric: 20.4923 - ssim_metric: 0.5943 - val_loss: 0.4046 - val_mae: 0.0653 - val_psnr_metric: 20.8372 - val_ssim_metric: 0.5957
# Epoch 42/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 36s 177ms/step - loss: 0.4049 - mae: 0.0691 - psnr_metric: 20.5201 - ssim_metric: 0.5951 - val_loss: 0.4047 - val_mae: 0.0668 - val_psnr_metric: 20.6969 - val_ssim_metric: 0.5957
# Epoch 43/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 171ms/step - loss: 0.4042 - mae: 0.0685 - psnr_metric: 20.5761 - ssim_metric: 0.5958 - val_loss: 0.4069 - val_mae: 0.0659 - val_psnr_metric: 20.8198 - val_ssim_metric: 0.5935
# Epoch 44/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 168ms/step - loss: 0.4036 - mae: 0.0680 - psnr_metric: 20.6298 - ssim_metric: 0.5964 - val_loss: 0.4108 - val_mae: 0.0643 - val_psnr_metric: 20.9502 - val_ssim_metric: 0.5896
# Epoch 45/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.4035 - mae: 0.0680 - psnr_metric: 20.6313 - ssim_metric: 0.5965 - val_loss: 0.4038 - val_mae: 0.0654 - val_psnr_metric: 20.8177 - val_ssim_metric: 0.5965
# Epoch 46/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.4023 - mae: 0.0676 - psnr_metric: 20.6762 - ssim_metric: 0.5977 - val_loss: 0.4081 - val_mae: 0.0646 - val_psnr_metric: 20.9252 - val_ssim_metric: 0.5922
# Epoch 47/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.4017 - mae: 0.0673 - psnr_metric: 20.7075 - ssim_metric: 0.5983 - val_loss: 0.4082 - val_mae: 0.0656 - val_psnr_metric: 20.8189 - val_ssim_metric: 0.5921
# Epoch 48/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.4016 - mae: 0.0670 - psnr_metric: 20.7306 - ssim_metric: 0.5984 - val_loss: 0.4060 - val_mae: 0.0649 - val_psnr_metric: 20.8957 - val_ssim_metric: 0.5943
# Epoch 49/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 166ms/step - loss: 0.4010 - mae: 0.0667 - psnr_metric: 20.7642 - ssim_metric: 0.5990 - val_loss: 0.4047 - val_mae: 0.0633 - val_psnr_metric: 21.0729 - val_ssim_metric: 0.5957
# Epoch 50/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.4003 - mae: 0.0666 - psnr_metric: 20.7809 - ssim_metric: 0.5997 - val_loss: 0.4048 - val_mae: 0.0638 - val_psnr_metric: 21.0018 - val_ssim_metric: 0.5956
# Epoch 51/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.4004 - mae: 0.0665 - psnr_metric: 20.7887 - ssim_metric: 0.5996 - val_loss: 0.4070 - val_mae: 0.0653 - val_psnr_metric: 20.8547 - val_ssim_metric: 0.5934
# Epoch 52/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.4006 - mae: 0.0665 - psnr_metric: 20.7930 - ssim_metric: 0.5994 - val_loss: 0.4059 - val_mae: 0.0642 - val_psnr_metric: 20.9862 - val_ssim_metric: 0.5944
# Epoch 53/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 166ms/step - loss: 0.3998 - mae: 0.0663 - psnr_metric: 20.8078 - ssim_metric: 0.6002 - val_loss: 0.4130 - val_mae: 0.0657 - val_psnr_metric: 20.7884 - val_ssim_metric: 0.5873
# Epoch 54/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3992 - mae: 0.0660 - psnr_metric: 20.8395 - ssim_metric: 0.6008 - val_loss: 0.4116 - val_mae: 0.0655 - val_psnr_metric: 20.8243 - val_ssim_metric: 0.5887
# Epoch 55/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 166ms/step - loss: 0.3991 - mae: 0.0661 - psnr_metric: 20.8340 - ssim_metric: 0.6009 - val_loss: 0.4063 - val_mae: 0.0667 - val_psnr_metric: 20.7337 - val_ssim_metric: 0.5941
# Epoch 56/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3992 - mae: 0.0660 - psnr_metric: 20.8357 - ssim_metric: 0.6008 - val_loss: 0.4121 - val_mae: 0.0653 - val_psnr_metric: 20.8557 - val_ssim_metric: 0.5882
# Epoch 57/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3987 - mae: 0.0657 - psnr_metric: 20.8686 - ssim_metric: 0.6013 - val_loss: 0.4049 - val_mae: 0.0687 - val_psnr_metric: 20.5163 - val_ssim_metric: 0.5955
# Epoch 58/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3986 - mae: 0.0657 - psnr_metric: 20.8612 - ssim_metric: 0.6014 - val_loss: 0.4119 - val_mae: 0.0677 - val_psnr_metric: 20.6035 - val_ssim_metric: 0.5884
# Epoch 59/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3981 - mae: 0.0654 - psnr_metric: 20.8967 - ssim_metric: 0.6019 - val_loss: 0.4057 - val_mae: 0.0669 - val_psnr_metric: 20.6873 - val_ssim_metric: 0.5947
# Epoch 60/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3975 - mae: 0.0654 - psnr_metric: 20.9035 - ssim_metric: 0.6025 - val_loss: 0.4052 - val_mae: 0.0694 - val_psnr_metric: 20.4272 - val_ssim_metric: 0.5952
# Epoch 61/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3975 - mae: 0.0653 - psnr_metric: 20.9020 - ssim_metric: 0.6025 - val_loss: 0.4017 - val_mae: 0.0664 - val_psnr_metric: 20.7256 - val_ssim_metric: 0.5986
# Epoch 62/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3975 - mae: 0.0653 - psnr_metric: 20.9105 - ssim_metric: 0.6025 - val_loss: 0.3997 - val_mae: 0.0652 - val_psnr_metric: 20.8748 - val_ssim_metric: 0.6007
# Epoch 63/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 166ms/step - loss: 0.3969 - mae: 0.0652 - psnr_metric: 20.9204 - ssim_metric: 0.6031 - val_loss: 0.4073 - val_mae: 0.0685 - val_psnr_metric: 20.5188 - val_ssim_metric: 0.5931
# Epoch 64/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3960 - mae: 0.0648 - psnr_metric: 20.9594 - ssim_metric: 0.6040 - val_loss: 0.4089 - val_mae: 0.0659 - val_psnr_metric: 20.7883 - val_ssim_metric: 0.5914
# Epoch 65/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3962 - mae: 0.0650 - psnr_metric: 20.9409 - ssim_metric: 0.6038 - val_loss: 0.4091 - val_mae: 0.0679 - val_psnr_metric: 20.6000 - val_ssim_metric: 0.5912
# Epoch 66/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 166ms/step - loss: 0.3963 - mae: 0.0652 - psnr_metric: 20.9299 - ssim_metric: 0.6037 - val_loss: 0.4120 - val_mae: 0.0694 - val_psnr_metric: 20.3831 - val_ssim_metric: 0.5883
# Epoch 67/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3958 - mae: 0.0649 - psnr_metric: 20.9575 - ssim_metric: 0.6042 - val_loss: 0.4028 - val_mae: 0.0696 - val_psnr_metric: 20.4085 - val_ssim_metric: 0.5976
# Epoch 68/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3955 - mae: 0.0647 - psnr_metric: 20.9673 - ssim_metric: 0.6045 - val_loss: 0.4075 - val_mae: 0.0729 - val_psnr_metric: 20.0629 - val_ssim_metric: 0.5928
# Epoch 69/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3959 - mae: 0.0649 - psnr_metric: 20.9484 - ssim_metric: 0.6041 - val_loss: 0.4049 - val_mae: 0.0702 - val_psnr_metric: 20.3918 - val_ssim_metric: 0.5955
# Epoch 70/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3943 - mae: 0.0644 - psnr_metric: 21.0070 - ssim_metric: 0.6057 - val_loss: 0.4123 - val_mae: 0.0768 - val_psnr_metric: 19.6838 - val_ssim_metric: 0.5880
# Epoch 71/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3951 - mae: 0.0647 - psnr_metric: 20.9663 - ssim_metric: 0.6049 - val_loss: 0.4068 - val_mae: 0.0678 - val_psnr_metric: 20.5831 - val_ssim_metric: 0.5936
# Epoch 72/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3947 - mae: 0.0645 - psnr_metric: 20.9939 - ssim_metric: 0.6053 - val_loss: 0.4078 - val_mae: 0.0753 - val_psnr_metric: 19.7848 - val_ssim_metric: 0.5925
# Epoch 73/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3947 - mae: 0.0645 - psnr_metric: 20.9963 - ssim_metric: 0.6053 - val_loss: 0.3958 - val_mae: 0.0654 - val_psnr_metric: 20.8680 - val_ssim_metric: 0.6045
# Epoch 74/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3940 - mae: 0.0643 - psnr_metric: 21.0162 - ssim_metric: 0.6060 - val_loss: 0.4064 - val_mae: 0.0740 - val_psnr_metric: 19.9354 - val_ssim_metric: 0.5939
# Epoch 75/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3940 - mae: 0.0643 - psnr_metric: 21.0161 - ssim_metric: 0.6060 - val_loss: 0.4010 - val_mae: 0.0701 - val_psnr_metric: 20.3468 - val_ssim_metric: 0.5993
# Epoch 76/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3940 - mae: 0.0644 - psnr_metric: 21.0049 - ssim_metric: 0.6060 - val_loss: 0.3965 - val_mae: 0.0662 - val_psnr_metric: 20.7816 - val_ssim_metric: 0.6038
# Epoch 77/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3933 - mae: 0.0641 - psnr_metric: 21.0404 - ssim_metric: 0.6067 - val_loss: 0.3958 - val_mae: 0.0646 - val_psnr_metric: 20.9299 - val_ssim_metric: 0.6046
# Epoch 78/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3938 - mae: 0.0642 - psnr_metric: 21.0317 - ssim_metric: 0.6062 - val_loss: 0.3975 - val_mae: 0.0660 - val_psnr_metric: 20.8147 - val_ssim_metric: 0.6029
# Epoch 79/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 51s 255ms/step - loss: 0.3940 - mae: 0.0642 - psnr_metric: 21.0299 - ssim_metric: 0.6060 - val_loss: 0.3958 - val_mae: 0.0650 - val_psnr_metric: 20.8992 - val_ssim_metric: 0.6045
# Epoch 80/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 228ms/step - loss: 0.3932 - mae: 0.0641 - psnr_metric: 21.0430 - ssim_metric: 0.6068 - val_loss: 0.4026 - val_mae: 0.0663 - val_psnr_metric: 20.7895 - val_ssim_metric: 0.5978
# Epoch 81/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 166ms/step - loss: 0.3936 - mae: 0.0642 - psnr_metric: 21.0329 - ssim_metric: 0.6064 - val_loss: 0.3959 - val_mae: 0.0611 - val_psnr_metric: 21.3460 - val_ssim_metric: 0.6044
# Epoch 82/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 166ms/step - loss: 0.3927 - mae: 0.0640 - psnr_metric: 21.0603 - ssim_metric: 0.6073 - val_loss: 0.3936 - val_mae: 0.0640 - val_psnr_metric: 21.0399 - val_ssim_metric: 0.6068
# Epoch 83/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 166ms/step - loss: 0.3931 - mae: 0.0641 - psnr_metric: 21.0477 - ssim_metric: 0.6069 - val_loss: 0.3946 - val_mae: 0.0630 - val_psnr_metric: 21.1599 - val_ssim_metric: 0.6057
# Epoch 84/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 166ms/step - loss: 0.3924 - mae: 0.0641 - psnr_metric: 21.0503 - ssim_metric: 0.6076 - val_loss: 0.3936 - val_mae: 0.0610 - val_psnr_metric: 21.3623 - val_ssim_metric: 0.6067
# Epoch 85/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3922 - mae: 0.0641 - psnr_metric: 21.0453 - ssim_metric: 0.6078 - val_loss: 0.3946 - val_mae: 0.0640 - val_psnr_metric: 21.0724 - val_ssim_metric: 0.6057
# Epoch 86/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3918 - mae: 0.0638 - psnr_metric: 21.0823 - ssim_metric: 0.6082 - val_loss: 0.3963 - val_mae: 0.0660 - val_psnr_metric: 20.8107 - val_ssim_metric: 0.6040
# Epoch 87/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3922 - mae: 0.0639 - psnr_metric: 21.0656 - ssim_metric: 0.6078 - val_loss: 0.4005 - val_mae: 0.0658 - val_psnr_metric: 20.8619 - val_ssim_metric: 0.5998
# Epoch 88/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3927 - mae: 0.0640 - psnr_metric: 21.0655 - ssim_metric: 0.6073 - val_loss: 0.3979 - val_mae: 0.0619 - val_psnr_metric: 21.3143 - val_ssim_metric: 0.6025
# Epoch 89/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3917 - mae: 0.0639 - psnr_metric: 21.0769 - ssim_metric: 0.6083 - val_loss: 0.3933 - val_mae: 0.0634 - val_psnr_metric: 21.1341 - val_ssim_metric: 0.6070
# Epoch 90/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 168ms/step - loss: 0.3921 - mae: 0.0640 - psnr_metric: 21.0618 - ssim_metric: 0.6079 - val_loss: 0.3954 - val_mae: 0.0596 - val_psnr_metric: 21.5275 - val_ssim_metric: 0.6050
# Epoch 91/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 168ms/step - loss: 0.3910 - mae: 0.0635 - psnr_metric: 21.1138 - ssim_metric: 0.6090 - val_loss: 0.3969 - val_mae: 0.0626 - val_psnr_metric: 21.2203 - val_ssim_metric: 0.6034
# Epoch 92/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3912 - mae: 0.0636 - psnr_metric: 21.0996 - ssim_metric: 0.6088 - val_loss: 0.3940 - val_mae: 0.0595 - val_psnr_metric: 21.5234 - val_ssim_metric: 0.6063
# Epoch 93/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3907 - mae: 0.0634 - psnr_metric: 21.1274 - ssim_metric: 0.6093 - val_loss: 0.3926 - val_mae: 0.0603 - val_psnr_metric: 21.4452 - val_ssim_metric: 0.6077
# Epoch 94/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3909 - mae: 0.0636 - psnr_metric: 21.1071 - ssim_metric: 0.6091 - val_loss: 0.4028 - val_mae: 0.0607 - val_psnr_metric: 21.4534 - val_ssim_metric: 0.5976
# Epoch 95/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3903 - mae: 0.0636 - psnr_metric: 21.1127 - ssim_metric: 0.6097 - val_loss: 0.3960 - val_mae: 0.0598 - val_psnr_metric: 21.5524 - val_ssim_metric: 0.6043
# Epoch 96/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3905 - mae: 0.0635 - psnr_metric: 21.1178 - ssim_metric: 0.6095 - val_loss: 0.3930 - val_mae: 0.0600 - val_psnr_metric: 21.4658 - val_ssim_metric: 0.6074
# Epoch 97/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3903 - mae: 0.0635 - psnr_metric: 21.1251 - ssim_metric: 0.6097 - val_loss: 0.3940 - val_mae: 0.0598 - val_psnr_metric: 21.5047 - val_ssim_metric: 0.6063
# Epoch 98/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3899 - mae: 0.0634 - psnr_metric: 21.1339 - ssim_metric: 0.6101 - val_loss: 0.3920 - val_mae: 0.0595 - val_psnr_metric: 21.5587 - val_ssim_metric: 0.6083
# Epoch 99/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - loss: 0.3898 - mae: 0.0635 - psnr_metric: 21.1246 - ssim_metric: 0.6102 - val_loss: 0.3943 - val_mae: 0.0600 - val_psnr_metric: 21.5035 - val_ssim_metric: 0.6060
# Epoch 100/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 34s 168ms/step - loss: 0.3895 - mae: 0.0633 - psnr_metric: 21.1483 - ssim_metric: 0.6105 - val_loss: 0.3931 - val_mae: 0.0612 - val_psnr_metric: 21.3680 - val_ssim_metric: 0.6072

# %%
import datetime

# Récupérer la date et l'heure actuelle
now = datetime.datetime.now()
timestamp = now.strftime("%d%m%Y_%H%M")  # Format : jour mois année _ heure minute

# Construire le chemin de sauvegarde
save_path = f"./../models/autoencoder_base_ssim_{timestamp}.weights.h5"

# Sauvegarder
autoencoder.save_weights(save_path)

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()

# %%
import matplotlib.pyplot as plt

# Tracer l'évolution de MAE
plt.figure(figsize=(12, 8))
plt.plot(history.history['mae'], label='train MAE')
plt.plot(history.history['val_mae'], label='val MAE')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error (MAE)')
plt.title('MAE over Epochs')
plt.legend()
plt.show()

# Tracer l'évolution de SSIM
plt.figure(figsize=(12, 8))
plt.plot(history.history['ssim_metric'], label='train SSIM')
plt.plot(history.history['val_ssim_metric'], label='val SSIM')
plt.xlabel('Epochs')
plt.ylabel('Structural Similarity (SSIM)')
plt.title('SSIM over Epochs')
plt.legend()
plt.show()

# Tracer l'évolution de PSNR
plt.figure(figsize=(12, 8))
plt.plot(history.history['psnr_metric'], label='train PSNR')
plt.plot(history.history['val_psnr_metric'], label='val PSNR')
plt.xlabel('Epochs')
plt.ylabel('Peak Signal-to-Noise Ratio (PSNR)')
plt.title('PSNR over Epochs')
plt.legend()
plt.show()

# %%
import cv2

def variance_of_laplacian_rgb(image_rgb):
    image_rgb = np.array(image_rgb)  # Assure que c'est un array numpy
    if image_rgb.shape[-1] == 3:
        gray = cv2.cvtColor((image_rgb * 255).astype(np.uint8), cv2.COLOR_RGB2GRAY)
    else:
        gray = (image_rgb * 255).astype(np.uint8)
    laplacian = cv2.Laplacian(gray, cv2.CV_64F)
    return laplacian.var()

def tenengrad_rgb(image_rgb):
    image_rgb = np.array(image_rgb)  # Assure que c'est un array numpy
    if image_rgb.shape[-1] == 3:
        gray = cv2.cvtColor((image_rgb * 255).astype(np.uint8), cv2.COLOR_RGB2GRAY)
    else:
        gray = (image_rgb * 255).astype(np.uint8)
    gx = cv2.Sobel(gray, cv2.CV_64F, 1, 0)
    gy = cv2.Sobel(gray, cv2.CV_64F, 0, 1)
    magnitude = np.sqrt(gx**2 + gy**2)
    return np.mean(magnitude)

# %%
import matplotlib.pyplot as plt

# Fonction SSIM
def ssim_metric(y_true, y_pred):
    return tf.reduce_mean(tf.image.ssim(y_true, y_pred, max_val=1.0))

# Fonction PSNR
def psnr_metric(y_true, y_pred):
    return tf.reduce_mean(tf.image.psnr(y_true, y_pred, max_val=1.0))

# Fonction MAE
def mae_metric(y_true, y_pred):
    return tf.reduce_mean(tf.abs(y_true - y_pred))

def show_original_vs_decoded_with_sharpness(noisy_dataset, clean_dataset, model, n=10):
    noisy_images, _ = next(iter(noisy_dataset))
    clean_images, _ = next(iter(clean_dataset))

    decoded_images = model.predict(noisy_images)

    plt.figure(figsize=(18, 8))
    for i in range(n):
        noisy = noisy_images[i].numpy()
        original = clean_images[i].numpy()
        decoded = decoded_images[i]

        # Calcul des métriques
        sharp_orig_lap = variance_of_laplacian_rgb(original)
        sharp_dec_lap = variance_of_laplacian_rgb(decoded)

        sharp_orig_ten = tenengrad_rgb(original)
        sharp_dec_ten = tenengrad_rgb(decoded)

        ssim_val = ssim_metric(original, decoded).numpy()
        psnr_val = psnr_metric(original, decoded).numpy()
        mae_val = mae_metric(original, decoded).numpy()

        # Score en % de netteté
        sharpness_percent_lap = (sharp_dec_lap / sharp_orig_lap) * 100 if sharp_orig_lap != 0 else 0
        sharpness_percent_ten = (sharp_dec_ten / sharp_orig_ten) * 100 if sharp_orig_ten != 0 else 0

        # --- Affichage ---
        
        # Image bruitée (entrée)
        ax = plt.subplot(3, n, i + 1)
        plt.imshow(noisy)
        plt.title("Bruitée")
        plt.axis("off")

        # Image originale
        ax = plt.subplot(3, n, n + i + 1)
        plt.imshow(original)
        plt.title(f"Originale\nLap: {sharp_orig_lap:.1f} | Ten: {sharp_orig_ten:.1f}")
        plt.axis("off")

        # Image reconstruite
        ax = plt.subplot(3, n, 2 * n + i + 1)
        plt.imshow(decoded)
        plt.title(
            f"Reconstruite\n"
            f"Lap: {sharp_dec_lap:.1f} ({sharpness_percent_lap:.1f}%)\n"
            f"Ten: {sharp_dec_ten:.1f} ({sharpness_percent_ten:.1f}%)\n"
            f"SSIM: {ssim_val:.3f} | PSNR: {psnr_val:.1f}\n"
            f"MAE: {mae_val:.4f}"
        )
        plt.axis("off")

    plt.tight_layout()
    plt.show()

# %%
show_original_vs_decoded_with_sharpness(noisy_test_ds, test_ds, autoencoder, n=5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 991ms/step
